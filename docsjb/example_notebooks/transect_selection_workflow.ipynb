# %% [markdown]
# # EchoPro Transect Subset Workflow

# %% [markdown]
# ## Import libraries and configure the Jupyter notebook

# %%
# libraries used in the Notebook
import matplotlib.pyplot as plt
import math 
import numpy as np 

# Python version of EchoPro
import EchoPro

# Allows us to grab the SemiVariogram class so we can use its models
from EchoPro.computation import SemiVariogram as SV

# obtain all visualization routines
from EchoPro.visualization import plot_layered_points, plot_kriging_results

# Allows us to easily use matplotlib widgets in our Notebook
# %matplotlib widget

# %% [markdown]
# ## Set up  EchoPro for a specific survey year

# %% [markdown]
# ### Initialize EchoPro object  using configuration files
#
# * `initialization_config.yml` -- parameters independent of survey year
# * `survey_year_2019_config.yml` -- parameters specific to survey year
# * `source` -- Define the region of data to use e.g. US, CAN, US & CAN
# * `exclude_age1` -- States whether age 1 hake should be included in analysis.

# %%
# %%time
survey_2019 = EchoPro.Survey(init_file_path='../config_files/initialization_config.yml',
                             survey_year_file_path='../config_files/survey_year_2019_config.yml',
                             source=3, 
                             exclude_age1=True)
# Out:
# A full check of the initialization file contents needs to be done!
# A check of the survey year file contents needs to be done!
# CPU times: user 4.93 ms, sys: 445 µs, total: 5.37 ms
# Wall time: 5.58 ms

# %% [markdown]
# ### Load and process input data
# * This data is stored in `survey_2019`

# %%
# %%time 
survey_2019.load_survey_data()
# Out:
# CPU times: user 1.19 s, sys: 12.8 ms, total: 1.21 s
# Wall time: 1.2 s

# %%
survey_2019.nasc_df.head()
# Out:
#               vessel_log_start  vessel_log_end   latitude   longitude  \
# transect_num
# 1                   744.016009      744.491145  34.397267 -121.143005
# 1                   744.500276      744.995605  34.397391 -121.133196
# 1                   745.004125      745.499447  34.397435 -121.123057
# 1                   745.508199      745.994306  34.397394 -121.112871
# 1                   746.003214      746.495701  34.397437 -121.102888
#
#               stratum_num  transect_spacing  NASC  haul_num
# transect_num
# 1                       1              10.0   0.0         0
# 1                       1              10.0   0.0         0
# 1                       1              10.0   0.0         0
# 1                       1              10.0   0.0         0
# 1                       1              10.0   0.0         0

# %% [markdown]
# ### Select a subset of the available transects to analyze

# %%
# obtain all unique transects in nasc_df
unique_transects = survey_2019.nasc_df.index.unique().values

# %%
# set the percentage of transects that should be removed
removal_percentage = 50.0

# determine the number of transects that should be selected
num_sel_transects = math.floor(len(unique_transects) * (1.0 - removal_percentage / 100.0))

# initialize the random number generator object and fix the seed
rng = np.random.default_rng(seed=1234)

# randomly select transects without replacement
selected_transects = list(rng.choice(unique_transects, num_sel_transects, replace=False))

# %% [markdown]
# ### Compute the areal biomass density on subset of transects
# * The areal biomass density is stored in `survey_2019.bio_calc.transect_results_gdf` as `biomass_density_adult`

# %%
# %%time
survey_2019.compute_biomass_density(selected_transects=selected_transects)
# Out:
# CPU times: user 104 ms, sys: 7 µs, total: 104 ms
# Wall time: 104 ms

# %%
survey_2019.bio_calc.transect_results_gdf.head()
# Out:
#                latitude   longitude  stratum_num  transect_spacing  \
# transect_num
# 5             35.065000 -120.726321            1           9.99037
# 5             35.064833 -120.734500            1           9.99037
# 5             35.064667 -120.744833            1           9.99037
# 5             35.064333 -120.754879            1           9.99037
# 5             35.063833 -120.765167            1           9.99037
#
#               biomass_density_adult  interval_area_nmi2  biomass  \
# transect_num
# 5                               0.0            3.928483      0.0
# 5                               0.0            5.039252      0.0
# 5                               0.0            4.975134      0.0
# 5                               0.0            5.025835      0.0
# 5                               0.0            4.951517      0.0
#
#                                  geometry
# transect_num
# 5             POINT (-120.72632 35.06500)
# 5             POINT (-120.73450 35.06483)
# 5             POINT (-120.74483 35.06467)
# 5             POINT (-120.75488 35.06433)
# 5             POINT (-120.76517 35.06383)

# %%
print(f"Total Biomass Estimate without Kriging: {1e-6*survey_2019.bio_calc.transect_results_gdf.biomass.sum():.3f} kmt")
# Out:
# Total Biomass Estimate without Kriging: 482.380 kmt

# %% [markdown]
# **Note:**
#
# **After the biomass density has been calculated using the selected transects, all steps that we have previously ran can be completed. However, it is important to note that it is suggested that one computes the semi-variogram parameters using the full data set, rather than a subset of transects. To remind the user of this, a warning will be raised if the user chooses to run the semi-variogram routine (we will demonstrate this later).**

# %% [markdown]
# ## Jolly-Hampton CV Analysis
#
# * Compute the mean of the Jolly-Hampton CV value on data that has not been Kriged
# * Note: the algorithm used to compute this value is random in nature

# %%
# %%time
CV_JH_mean = survey_2019.run_cv_analysis(kriged_data=False)
# Out:
# CPU times: user 1.07 s, sys: 8.31 ms, total: 1.08 s
# Wall time: 1.08 s

# %%
print(f"Mean Jolly-Hampton CV: {CV_JH_mean:.4f}")
# Out:
# Mean Jolly-Hampton CV: 0.2595

# %% [markdown]
# ## Obtain Kriging Mesh Data

# %% [markdown]
# ### Access Kriging mesh object
# * Reads mesh data files specified by `survey_2019`

# %%
krig_mesh = survey_2019.get_kriging_mesh()

# %% [markdown]
# #### Plot the Mesh, Transects and smoothed isobath contour
#
# * Generate interactive map using the Folium package
# * Mesh points are in gray
# * Transect points are represented by a changing color gradient
# * Smoothed contour points (200m isobath) are in blue

# %%
fmap = plot_layered_points(krig_mesh, plot_mesh_points=False)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2fa03aa086cef1da9720fcee7a778a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2fa03aa086cef1da9720fcee7a778a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2fa03aa086cef1da9720fcee7a778a0 = L.map(
#                 &quot;map_b2fa03aa086cef1da9720fcee7a778a0&quot;,
#                 {
#                     center: [44.61, -125.66],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3df878bb828a879f8695c00026ca6d10 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b2fa03aa086cef1da9720fcee7a778a0);
#
#
#             var feature_group_00da4d56595590b63a37c43fce65443c = L.featureGroup(
#                 {}
#             ).addTo(map_b2fa03aa086cef1da9720fcee7a778a0);
#
#
#             var circle_marker_59b4d7ab353d97e42139491a882bf6a3 = L.circleMarker(
#                 [35.065, -120.72632139],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#46327e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#46327e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00da4d56595590b63a37c43fce65443c);
#
#
#             var circle_marker_b435be1f0e0186cf97259809b489631b = L.circleMarker(
#                 [35.06483333, -120.7345],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#46327e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#46327e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00da4d56595590b63a37c43fce65443c);
#
#
#             var circle_marker_7a05624c5967fed000963132c3853d77 = L.circleMarker(
#                 [35.06466667, -120.74483333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#46327e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#46327e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00da4d56595590b63a37c43fce65443c);
#
#
#             var circle_marker_18f8db9763cb1a56c806b810c9f9a3c4 = L.circleMarker(
#                 [35.06433333, -120.75487887],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#46327e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#46327e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00da4d56595590b63a37c43fce65443c);
#
#
#             var circle_marker_37726bdfee08744be324a3472eb7cbda = L.circleMarker(
#                 [35.06383333, -120.76516667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#46327e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#46327e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_00da4d56595590b63a37c43fce65443c);
#
#
#             var circle_marker_9cc3042582b36cea8f8b64551e161637 = L.circleMarker(
#                 [35.06366667, -120.77518],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#46327e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#46327e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJo

# %% [markdown]
# ## Apply coordinate transformations
# * Longitude transformation
# * Lat/Lon to distance

# %% [markdown]
# ### Transect points

# %%
krig_mesh.apply_coordinate_transformation(coord_type='transect')

# %% [markdown]
# ### Mesh points

# %%
krig_mesh.apply_coordinate_transformation(coord_type='mesh')

# %%
# plot the transformed mesh points 
plt.plot(krig_mesh.transformed_mesh_df.x_mesh, 
         krig_mesh.transformed_mesh_df.y_mesh, 'r*', markersize=1.25)
plt.show()

# %% [markdown]
# ## Try to initialize the Semi-Variogram

# %%
semi_vario = survey_2019.get_semi_variogram(
    krig_mesh,
    params=dict(nlag=30, lag_res=0.002)
)
# Out:
# /usr/mayorgadat/workmain/acoustics/gh/uw-echospace/EchoPro/EchoPro/survey.py:474: UserWarning: The biomass data being used is a subset of the full dataset. It is recommended that you use the biomass data created from the full dataset. To silence this warning set the warning argument to False.
#   warn(

# %% [markdown]
# **As expected, a warning pops up and reminds us not to run the semi-variogram calculation and model fitting using the data that was generated from a subset of the full data set.**

# %% [markdown]
# ## Perform Ordinary Kriging of areal biomass density
#
# * transformed mesh points
# * semi-variogram model
# * areal biomass density

# %% [markdown]
# ### Initialize Kriging routine

# %%
kriging_params = dict(
    # kriging parameters
    k_max=10,
    k_min=3,
    R=0.0226287,
    ratio=0.001,
    
    # parameters for semi-variogram model
    s_v_params={'nugget': 0.0, 'sill': 0.95279, 'ls': 0.0075429,
                'exp_pow': 1.5, 'ls_hole_eff': 0.0},
    
    # grab appropriate semi-variogram model
    s_v_model=SV.generalized_exp_bessel
)

# initalize kriging routine
krig = survey_2019.get_kriging(kriging_params)

# %% [markdown]
# ### Perform Kriging
# * Also generates total biomass at mesh points

# %%
# %%time
krig.run_biomass_kriging(krig_mesh)
# Out:
# CPU times: user 2.86 s, sys: 863 ms, total: 3.72 s
# Wall time: 2.08 s

# %%
krig_results = survey_2019.bio_calc.kriging_results_gdf

# %% [markdown]
# Convert from kg to kmt

# %%
krig_results.biomass = 1e-6 * krig_results.biomass

# %%
print(f"Total Kriged Biomass Estimate: {krig_results.biomass.sum():.3f} kmt")
# Out:
# Total Kriged Biomass Estimate: 1060.860 kmt

# %% [markdown]
# ### Plot Kriged Biomass estimate in kmt

# %%
# plot mesh points with biomass values > 0
plot_kriging_results(krig_results, krig_field_name="biomass", greater_than_0=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71eba3b4971b1f27e5d061dc640e73a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71eba3b4971b1f27e5d061dc640e73a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71eba3b4971b1f27e5d061dc640e73a4 = L.map(
#                 &quot;map_71eba3b4971b1f27e5d061dc640e73a4&quot;,
#                 {
#                     center: [44.61, -125.66],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b03963d0e5ceafb5ab07f9969e7e9493 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71eba3b4971b1f27e5d061dc640e73a4);
#
#
#             var circle_marker_8f3156b03838ccc628c9f492ccc1f03e = L.circleMarker(
#                 [48.8909392554, -126.02405959],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3484feff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3484feff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_71eba3b4971b1f27e5d061dc640e73a4);
#
#
#             var circle_marker_f4ea8b9c1d49635d356b1773d4a599bc = L.circleMarker(
#                 [48.8491975468, -126.024042768],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3f7df0ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3f7df0ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_71eba3b4971b1f27e5d061dc640e73a4);
#
#
#             var circle_marker_28cb45c0d32b32b11df4d57e2aefdd47 = L.circleMarker(
#                 [48.8074610438, -126.02402597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#407cefff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#407cefff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_71eba3b4971b1f27e5d061dc640e73a4);
#
#
#             var circle_marker_a8b933f6a6cadf07c96b59a92aae3b92 = L.circleMarker(
#                 [48.4320609216, -126.023875837],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8b4b91ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#8b4b91ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_71eba3b4971b1f27e5d061dc640e73a4);
#
#
#             var circle_marker_643d89673b20b4cafc83414c25d3517f = L.circleMarker(
#                 [48.3903745313, -126.023859272],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ba2d56ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ba2d56ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_71eba3b4971b1f27e5d061dc640e73a4);
#
#
#             var circle_marker_b0143cb0354a5cf6a072681b4f71361d = L.circleMarker(
#                 [48.3486929604, -126.023842729],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4977e4ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#4977e4ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_71eba3b4971b1f27e5d061dc640e73a4);
